# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install scrapy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.9/272.9 kB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.1/246.1 kB 18.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 67.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 7.9 MB/s eta 0:00:00
# ...

# %%
# !scrapy startproject ui_final2
# Out:
# New Scrapy project 'ui_final2', using template directory '/usr/local/lib/python3.9/dist-packages/scrapy/templates/project', created in:
#     /content/ui_final2
#
# You can start your first spider with:
#     cd ui_final2
#     scrapy genspider example example.com

# %%
# %cd ui_final2
# Out:
# /content/ui_final2

# %%
# %cd ui_final2
# Out:
# /content/ui_final2/ui_final2

# %%
# %cd spiders
# Out:
# /content/ui_final2/ui_final2/spiders

# %%
# !scrapy genspider mobiles www.mobile.ir/brands/7-apple.aspx
# Out:
# Created spider 'mobiles' using template 'basic' in module:
#   ui_final2.spiders.mobiles

# %%
# !scrapy runspider mobiles.py
# Out:
# 2023-04-24 09:03:46 [scrapy.utils.log] INFO: Scrapy 2.8.0 started (bot: ui_final2)
# 2023-04-24 09:03:46 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.1, Twisted 22.10.0, Python 3.9.16 (main, Dec  7 2022, 01:11:51) - [GCC 9.4.0], pyOpenSSL 23.1.1 (OpenSSL 3.1.0 14 Mar 2023), cryptography 40.0.2, Platform Linux-5.10.147+-x86_64-with-glibc2.31
# 2023-04-24 09:03:46 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'ui_final2',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'ui_final2.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_LOADER_WARN_ONLY': True,
#  'SPIDER_MODULES': ['ui_final2.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2023-04-24 09:03:46 [asyncio] DEBUG: Using selector: EpollSelector
# ...

# %%
# !scrapy genspider comments www.mobile.ir
# Out:
# Created spider 'comments' using template 'basic' in module:
#   ui_final2.spiders.comments

# %%
# !scrapy runspider comments.py
# Out:
# 2023-04-24 09:05:23 [scrapy.utils.log] INFO: Scrapy 2.8.0 started (bot: ui_final2)
# 2023-04-24 09:05:23 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.1, Twisted 22.10.0, Python 3.9.16 (main, Dec  7 2022, 01:11:51) - [GCC 9.4.0], pyOpenSSL 23.1.1 (OpenSSL 3.1.0 14 Mar 2023), cryptography 40.0.2, Platform Linux-5.10.147+-x86_64-with-glibc2.31
# 2023-04-24 09:05:23 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'ui_final2',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'ui_final2.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_LOADER_WARN_ONLY': True,
#  'SPIDER_MODULES': ['ui_final2.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2023-04-24 09:05:23 [asyncio] DEBUG: Using selector: EpollSelector
# ...

# %%
import pandas as pd
data=pd.read_csv('/content/ui_final2/ui_final2/spiders/whole17.csv')
# data.shift(periods=1)
data.head(100)
# data.to_csv('/content/ui_final2/ui_final2/spiders/whole4.csv', index=False)
# Out:
#                نصب اپ بدون نیاز به اپ استور:برای اولین بار تو این فروم ها این اموزش رو میذارم فقط برای دوستانی که ایفون دارن و کاربر ios هستن.همونطور که فرمت فایل های نصبی اندروید apk هست ، فرمت فایل های نصبی ios هم ipa هست.در ابتدا شما بایستی با نصب برنامه altstore روی ویندوز یا مکینتاش خودتون (لپ تاپ یا دسکتاپ) نصبو سپس گوشی ایفون یا ایپدتونو به کامپیوتر وصل کنین و اپ استور الت استور رو روی گوشیتون با یه کلیک نصب کنیناولین قدم : دانلود ایکلود و آیتونز نسخه ویندوز نسخه ۶۴ بیتی:dl.jooda.ir/ios/iTunes.12.11.3.17.x64.zipdl.jooda.ir/ios/iCloud.Control.Panel.7.18.zipدومین قدم :‌نصب الت استور از وبسایت رسمی :cdn.altstore.io/file/altstore/altinstaller.zip(توجه : قبل از هر اقدامی لطفا از همه داده های ایفون خودتونتوسط ایتیونز ، فول بکاپ بگیرین)ــــــــــــــــــــــــــــــــــــــــــــــــــــــــپس از نصب همه و بکاپ گیری ، رو سیستمتون برنامهالت استور رو باز کنین :۱- آیفونتونو با کابل به کامپیوتر وصل کنین۲- از Notification Area (کنار تاریخ و ساعت) برنامه Install AltStore رو باز کنید و سپس 
# ...

# %%
cov = pd.read_csv("/content/ui_final2/ui_final2/spiders/whole17.csv",  names=["comments", "samsung", "apple"])
cov.to_csv("/content/ui_final2/ui_final2/spiders/final_comments17.csv",index=False)
cov.head()
# Out:
#                                             comments  samsung  apple
# 0              نصب اپ بدون نیاز به اپ استور:برای ...      NaN    NaN
# 1                                      » در پاسخ ...      NaN    NaN
# 2                                      » در پاسخ ...      NaN    NaN
# 3                                      » در پاسخ ...      NaN    NaN
# 4                                      » در پاسخ ...      NaN    NaN

# %%
num_rows = len(cov)

print(num_rows)
# Out:
# 5132
